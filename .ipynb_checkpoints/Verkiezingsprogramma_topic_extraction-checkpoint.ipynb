# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import re
import os
import random
import matplotlib.gridspec as gridspec
from collections import defaultdict
from sklearn.decomposition import PCA

# %%
from tensorflow.keras import backend as K
import tensorflow as tf

from tensorflow.keras.layers import Input, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

# %% [markdown]
# # Load word count table for all NOS articles

# %%
all_data = pd.read_csv('Data/NOS_articles_with_word_counts.csv')

# %%
all_data = all_data.set_index('Unnamed: 0')

# %%
all_data = all_data.loc[:, ~ all_data.columns.str.contains('Unnamed')]

# %%
all_data.shape
# Out:
# (42924, 13151)

# %% [markdown]
# ## Define key words per topic

# %%
topics = {
'Branden & brandweer':[ 'bosbranden','brand','bosbrandgebied','brandweer','vuur'],

'Politiek & verkiezingen':['verkiezingen','politiek','lijsttrekker','kamerverkiezingen','verkiezingen','oppositieleider','oppositie','parlementsverkiezingen','partijcongressen','referendumopkomst','referendum','verkiezing','stemmen','stembureau','democratie','stemmers','congreslid'],

'Politie':['politie','agent','agenten','politieagent','politiemissie','politiebureau','politiebond','politiegeweld', 'korpschef','politieactie'],

'Inlichtingendienst':['aftappen','aivd','inlichtingendienst','inlichtingendiensten','afluistermicrofoons','afluisteren','afluistermicrofoon','afluisterprogramma','nsa','telefoontaps','telefoontap','nsa','spionage'],

'Diplomatie':['diplomaat','diplomatie','ambassade','ambassadeur','sancties','onderhandelingen','onderhandeling','vredesonderhandelingen','vredesonderhandeling'],

'Discriminatie':['discriminatie','discrimineren','racisme','racist','ongelijkheid','neonazi','vrouwendiscriminatie','hakenkruizen','seksistisch','racistische','racistisch','seksist','antisemitisme'],

'Demonstraties':['demonstraties','demonstratie','protest','protesten','demonstreren','demonstrant','demonstranten','spandoek','spandoeken','protesteren'],

'Defensie':['defensie','militairen','militair','militaire','soldaten','leger', 'luchtmacht','dienstplicht','patrouilleschepen','marine','landmacht'],

'Duurzame energie':['duurzaam','duurzame','energietransitie','duurzaamheid','windenergie','zonnepanelen','zonnepaneel','klimaatneutraal', 'windmolen','windmolens','zonne-energie','waterstof'], 

'Klimaatverandering':['klimaatverandering','co2','co2-uitstoot','opwarming','klimaatcrisis','klimaat','klimaatneutraal','klimaattop','klimaatbeleid','klimaatmars','ijskappen','ijskap','klimaatbescherming','klimaatactivisten','klimaatactivist'],

'Rechtbank & rechter':['rechtbank','rechter','rechters','rechterstaat','veroordeling','straf','levenslang','doodstraf','gehoorzitting','strafhof', 'gevangenissen','gevangenis','taakstraf','gevangenisstraf','advocaat','advocaten','strafdossier'],

'Criminaliteit & drugs':['criminaliteit','drugs','drugshandel','drugsactie','drugssmokkel','drugspanden','drugsvangst','drugshandelaren','drugssmokkel','drugsnetwerk', 'cocainevangst','kartel','drugsgeld','witwassen','cocaine','heroine','drugspand','kartelbaas','xtc'], 

'Criminaliteit & geweld':['criminaliteit','slachtoffer','neergestoken','verdachte','geweld','steekpartij','neergestoken','crimineel','schietpartij','doodgeschoten','mishandeld','neersteken','liquidatie','doodslaan','doodsteken','daders','dader','schietincident','munitie','wapens'], 

'Diefstal':['inbreker','inbrekers','inbraak','diefstallen','diefstal','autodieven','dieven','plofkrakers','plofkraak','stelen','gestolen','woninginbraken','woninginbraak','zakkenrollers','zakkenroller'],

'Corruptie & fraude': ['corruptie','smeergeld','omkoping','omkopen','corruptiezaken','corruptiezaak','fraude','fraudezaak','fraudezaken','frauderen','corruptieschandaal','corrupte'],

'Veehouderijen & vlees':['vlees','vee','veehouderij','veehouders','veehouder','melkveehouders','vleesconsumptie','pluimvee','veeteelt','vleesleveranciers', 'varkenshouderij','varkenshouderijen', 'melkveehouderijen','melkveehouder','slagerijen','vleesverbruik','veestapel','slachterij','vleesleverancier'],

'Landbouw & boeren':['landbouw','boeren','boer','landbouwsector','akkerbouw','akker','oogst','akkers','oogsten','tulpentelers','tulpenteler', 'fruitteler','fruittelers','fruitoogst'],

'Werk':['werk','werkgever','werknemers','baan','banen','werkgelegenheid','werkloos','werkloosheid', 'salaris', 'arbeidsmarkt','arbeiders','arbeider','salarisverlaging'],

'Woningmarkt':['woningmarkt','woningcorporaties','huizenprijzen','woningtekort','woningen','koopwoning','huurprijs','huisbaas','huurwoning','woningnood','nieuwbouwprojecten','koopwoningen','huisbaas','huizenkopers','nieuwbouwwijk','nieuwbouwwoningen','huurhuizen','nieuwbouw','woonwijk','wonen','villa', 'huurprijzen','hypotheekrente','hypotheek','hypotheekverstrekkers','hypotheekverstrekker','hypotheken','hypotheekrenteaftrek','hypotheekregels'],

'Pensioen':['pensioen','pensioenstelsel','pensioenakkoord','pensioenleeftijd','pensioenpremies','pensioenstelsels', 'pensioenen','pensioenoverleg','pensioenfondsen','pensioenpremie','pensioenhervorming','pensioenfonds'],

'Oorlog & conflicten':['oorlog','conflict','conflicten','doden','dood','gewonden','bom','bommen','bombardement','luchtaanvallen','taliban','isis','qaida', 'konvooi','terreurgroep','gevechtshelikopter','raketaanval','wapens','kindsoldaten','separatisten'],

'Stikstof':['stikstof','stikstofcrisis','stikstofuitstoot','stikstofregels','stikstofvonnis', 'stikstofcijfers', 'stikstofplannen','stikstofwet', 'stikstofmaatregel','stikstofmaatregels', 'stikstofberekeningen', 'stikstofcijfer', 'stikstofdossier', 'stikstofneerslag','stikstofactivist','stikstofproblemen','stikstofmaatregelen'],

'Kernenergie':['kernenergie','kerncentrale','kerncentrales','nucleaire','nucleair','kernafval','atoombesluit','uraniummijnen','uranium','kernramp','jodiumpillen','stralingsrecord'],

'Belasting':['belasting','accijns','belastingen','belastingdienst','belastingtoeslag','tax','taks','winstbelasting','belastingparadijzen','belastingparadijs'],

'Vakbonden':['vakbonden','coa','vakbond','fnv'],

'Reizen & Openbaar vervoer':['vervoer','trein','ns','bus','reiziger','reizigers','treinstations','treinstation','spoorweg','prorail','buschauffeur'],

'Studielening':['studieschuld','studielening','leenstelsel','studiebeurs','stufi','leenstelselgeld'],

'Onderwijs':['leraar','school','scholen','studeren','universiteit','studenten','hoogleraar','universiteiten','onderwijsinspectie', 'student','studerende','opleiding','docent','docenten','lerares'],

'Vliegen':['vliegen','vliegtuig','klm','ryanair','luchthavens','luchthaven','boeing','vliegveld','vliegtickets','schiphol','airbus','easyjet'], 

'Vakantie & tourisme':['tourisme','touristen','tourist','vakantie','vakantiedagen','vakantiebestemming','vakantiebestemmingen','vakantiehuis','vakantiehuisjes','zomervakantie',
'vakantiehuisje','vakantiepark','vakantieparken'],

'Seksueel misbruik & seksualiteit':['misbruik','seksueel','verkrachten','verkrachting','aanranding','aanranden','verkrachter','seks','misbruikslachtoffer','misbruikslachtoffers'],

'Voetbal':['voetbal','voetballen','uefa','voetballer','voetbalster','feyenoord','psv','ajax'],

'Data & privacy & algoritmes':['privacywet','privacy','privacyschender','priveschandalen','privacyproblemen','datalek','datalekken', 'privacyrecht','data','algoritmes','algoritme'],

'Sport':['sport','sporten','wedstrijd','medaille','wereldkampioen','wielrenner','wielrennen','zwemmen','hockey','coach', 'kampioen','trainer','tennis','volleybal','honkbal','olympisch','olympische','tourwinnaar'],

'Zorg':['ziekenhuis','verpleger','verplegers','arts','artsen','ziekenhuizen','patiënten','patiënt','dokter','huisarts','zorginstelling','gezondheid', 'zorgverzekeraars','zorgverzekeraar','verpleger','verplegers','verpleging','woonzorgcentrum','ouderzorg','verpleeghuizen','verpleeghuis','gehandicaptenzorg'],

'Coronavirus':['coronavirus','corona','covid19','covid-19','besmetting','besmettingen','covid-patiënten','coronavaccin','coronamaatregelen','coronamaatregel', 'coronapatiënt','coronapatiënten','coronapakket','coronapatient','coronapatienten'],

'Asielzoekers & vluchtelingen':['asielzoekers','asielzoeker','asielzoekerscentra','asiel','asielzoekerscentrum','vluchtelingen','asielzoekersgroep','opvangkampen','asielprocedure',
'vluchteling','vluchtelingenstroom','migranten','migrantenkamp','vluchtelingenkamp','vluchtelingenbootjes','vluchtelingenboot'],

'Europese Unie':['europees','europese','europa','eu','eu-lidstaat','eu-lidstaten','eu-leiders','eu-leider'],

'Afval':['afval','vuilnis','zwerfafval','plastic','recycling','recycle','afvalberg','afvalstort','recyclebaar','luchtvervuiling','statiegeld', 'prullenbakken','prullenbak','afvalcontainer','recyclingbedrijf','afvalverwerker','vervuild','vervuilde'],

'Homoseksualiteit': ['homoseksualiteit','homoseksuelen','homoseksueel','gay','homo','homoacceptatie','homos','homorechten','lesbische','lesbisch'],

'Medicijnen':['medicijnen','farmaceut','geneesmiddelen','geneesmiddel','medicijn','geneesmiddelfabrikant','vaccin','vaccinatie', 'geneesmiddelfabrikanten','farmaceutische','farmaceutisch','pijnstiller','antibiotica'], 

'Gas':['gas','gaswinning','aardgas','gasboring','schaliegas','gasveld'],

'Natuur & dieren':['natuur','natuurgebied','dieren','dier','vogels','insecten','insect','boom','plantensoorten','milieu','schapen','veluwe','broedplek','oerwoud','weilanden','vijver', 'natuurreservaten','natuurreservaat','regenwoud','zoogdieren','staatsbosbeheer', 'weiland','zoogdieren','dierentuin','biodiversiteit','zoogdier','planten','plant','organisme','organismen'],

'Aanslagen & terrorisme':['aanslag','aanslagen','bom','terrorisme','terrorist','terreuraanslagen','terreuraanslag','verijdelt','zelfmoordaanslagen','zelfmoordaanslag','autobom','terrorismeverdachte','terreurgroep','terreur'],

'Banken':['bank','banken','bankencrisis','rente','rabobank','triodos','ing','internetbankieren','amro','bankieren','bankier','ecb'],

'Verkeer':['auto','verkeer','vrachtwagen','snelweg','snelwegen','maximumsnelheid','spoorwegovergangen','buschauffeur','taxi','automobilisten','automobilist','asfalt','automobiliste', 'bestuurder','vrachtwagens','verkeersongeluk','botsing'],

'Bedrijfsleven & economie':['bedrijfsleven','bedrijven','mkb','bedrijf','bedrijven','winst','omzet','aex','handelscontracten',
'aandelen','aandeelhouders','aandeelhouder','aandelenbeurs','miljardenverlies','failliet','faillissement'],


'Consumenten':['kopen','consumenten','producten','winkels','kleding','consumeren','consumentenbond','marketing','scheepvaartmuseum','aankoop','consument','winkel','winkelen', 'aankopen','shoppen'],

'Cultuur & musea': [ 'rijksmuseum','toneel','theater','musea','museum', 'cultuur','cultureel','kunstwerk','kunstenaar','kunstenaren','straatartiesten','theatermakers', 'disney','hollywood','film','bioscoop','cabaretier','filmindustrie','oscar','artiesten','artiest','acteur','cultuurprijs'],

'Olie & kolen & grijze energie':['olie','olieproductie','olieproducerende','olieproducent','kerosine','benzine','diesel','shell','olieplatforms','olieplatform','oliereus','bp','benzineprijs','benzineprijzen','kolencentrale','kolencentrales','kolencentralen','olieraffinaderijen','olieraffinaderij','kolengestookte','steenkool','fossiele','olieboringen', 'olieboring','steenkool','brandstofprijs','brandstofprijzen','olieprijs','olieprijzen'],

'Prostitutie & mensenhandel':['prostitutie','bordeel','bordelen','sekswerker','sekswerkers','prostituee','prostituees','prostitueerde','mensensmokkelnetwerk', 'mensenhandel','mensensmokkel','mensenhandelaar','mensenhandelaars','mensenhandelaren','mensensmokkelaar'],

'Zwangerschap & abortus ':['zwangerschap','zwanger','zwangeren','miskramen','verpleegkundigen','verpleegkundige','baby','bevalling','moeder','moeders','baarmoeder','abortus','abortuskliniek','abortusklinieken','abortusmanifestatie','sterilisatie','abortusreferendum','anticonceptie','abortusklinieken'],

'Festival & feesten':['festival','feestende','feesten','feest','festivals','festivalseizoen','pinkpop','lowlands','festivalbezoekers','festivalbezoeker',
'muziek','rockmuzikant','muzikant','muzikanten','carnaval'],

'Scheepvaart':['vrachtschip','schepen','schip','vrachtschepen','scheepvaart'],

'Islam':['islam','moskee','imams','imam','allah','koran','islamitisch','islamitische','moskeeen','moskeeën'],

'Christendom':['christendom','christus','jezus','kerk','priester','paus','kerkdienst','priesters','pastor','katholieke','vaticaan','kerkdiensten'],

'Wiet': ['wiet','wietteelt','coffeeshop','cannabis','wietplant','coffeeshops','wietroker','jointjes','wietbeleid','hennepkwekerijen','wietteler','wiettelers','wietproef','hennepkwekerij','hennep','wietplantage','wietplantages'],


'China':['china','xi','chinees','chinese','chinezen','ccp'],

'Natuurramp & extreem weer':['orkaan','overstroming','bosbranden','bosbrand','overstromingen','aardbeving','overstromingsgebied','droogte','vulkaanuitbarsting','vulkaan','hittegolf', 'wervelstorm','aardbevingen','tsunami','aardverschuiving','windstoten','noodweer','overstromingsgevaar','wateroverlast','stormschade','aardbevingen','natuurbrand','natuurbranden'],

'Mensenrechten': ['amnesty','mensenrechten','mensenrechtenorganisaties','mensenrechtenorganisatie','mensenrechtenactivist','mensenrechtenactivisten','kinderarbeid', 'dwangarbeid','meningsuiting','mensenrechtenschendingen','mensenrechtenadvocaat','mensenrechtenschenders','mensenrechtenschender'],

'Koningshuis':['koning','koningin','prinsessen','prinses','koningshuis','prins','koninginnedag','koningspaar'],

'Ruimtevaart':['ruimtecapsule','ruimtevaart','nasa','spacex','satelliet','satellieten','planeet','planeten','aardobservatiesatelliet', 'ruimtetelescoop','lancering','iss','astronaut','astronauten','ruimtevaart','zonnestelsel','sterrenstelsel'],


}

# Some special character removal
topics = {u: [ re.sub('[^A-Za-z0-9 ]+', '', t).lower() for t in v] for u,v in topics.items()}

# %% [markdown]
# # Classifier

# %% [markdown]
# ### Input matrix

# %%
# Make input for training 
X = all_data.fillna(0)
# Normalize word counts
X= (X.iloc[0:].T / X.iloc[0:] .sum(axis=1)).T

# %% [markdown]
# ### Labels

# %%
nr_to_label = { i:topic for i,(topic,words) in enumerate(topics.items())}

# %%
y = []
for art_word,row in X.iterrows():
    if( 'txt' in art_word):
        words_in_article = row[row > 0.001 ].index.tolist()
        zeros = np.zeros(len(topics) )
        for i,(topic,words) in enumerate(topics.items()):
            
            overlap = set(words_in_article).intersection(words)
            if( len(overlap) > 1):
                zeros[i] = 1
    
        if( sum(zeros) >= 5):
            zeros = np.zeros(len(topics) )
        
        zeros = list(zeros)
        y.append( zeros)
    else:
        print(row.name)
        zeros = list(np.zeros(len(topics)))
        y.append(zeros)
        
y = np.array(y)

# %%
y = pd.DataFrame(y, index = X.index )
y = y.rename(columns  = nr_to_label)

# %%
# Remove articles without label
art_sel = y.sum(axis=1)
art_sel = art_sel[art_sel!=0].index

# %%
X_sel = X.loc[art_sel]
y_sel = y.loc[art_sel]

# %%
len(art_sel)
# Out:
# 29970

# %% [markdown]
# ### Make classifier NN

# %%
# Define model
x_in = Input(shape=(X.shape[1],))

drop_1 = Dropout(0.2)(x_in)
D_1 =  Dense(200, activation='tanh')(drop_1)
drop_2 = Dropout(0.1)(D_1)
D_2 =  Dense(50, activation='tanh')(drop_2)
drop_3 = Dropout(0.1)(D_2)
D_3 =  Dense(y.shape[1], activation=None)(drop_3)

def custom_output(x):
    return tf.exp(x) / tf.reduce_sum(tf.exp(x), axis=1, keepdims=True)

max_layer = Lambda(custom_output,name='max')(D_3)

# Build model
model = Model(inputs=[x_in], outputs=max_layer)

# %% [markdown]
# ### Training

# %%
losses = []

# %%
optimizer = Adam(lr=1e-2)

# Classification performance
def loss_fn(y, y_pred):
    return CategoricalCrossentropy()(y, y_pred)


# Training steps
for i in range(10000):
    # Random training set
    mask = np.random.randint(0, 20, len(X_sel)) == 0

    with tf.GradientTape() as tape:
        predictions = model([X_sel.loc[mask]], training=True)
        loss = loss_fn(y_sel.loc[mask], predictions)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    losses.append(loss.numpy())

    print(sum(mask), loss.numpy())

# %%
ind = 20000
plt.plot(range(len(losses[ind:])),losses[ind:])
plt.plot(range(len(losses[ind:])),pd.Series(losses[ind:]).rolling(window=25,center=True).mean() )

# %%
X_pred = pd.DataFrame(model.predict(X_sel), index = X_sel.index ).rename(columns = nr_to_label)

# %%
probs_max = pd.DataFrame(probs_max)

# %%
probs_max.set_index(0).iloc[0:50]
# Out:
#                                                                                 1  \
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...       Bedrijfsleven & economie
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...  Olie & kolen & grijze energie
# 2265706-twee-belgische-kernreactoren-morgen-wee...                    Kernenergie
# 362503-jagende-juan-carlos-in-opspraak.html.txt                       Koningshuis
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...   Asielzoekers & vluchtelingen
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...       Bedrijfsleven & economie
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt                          Verkeer
# militair-artsen-en-verpleegkundigen-aan-de-slag...                           Zorg
# 2302970-dnb-president-knot-snel-beginnen-met-ko...                       Pensioen
# 2352429-haar-situatie-is-schrijnend-maar-nederl...            Rechtbank & rechter
# 407712-automobilist-eland-ontweken-beer-geraakt...                        Verkeer
# 2351459-eindhovense-studenten-presenteren-luca-...                          Afval
# 2275332-ministerie-voor-zover-bekend-geen-neder...            Oorlog & conflicten
# 2157810-milieuorganisaties-lanceren-groen-kiesk...                Natuur & dieren
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...        Zwangerschap & abortus
# 2278194-marokkaanse-christenen-hopen-op-meer-re...                    Christendom
# 2277311-afghaanse-migratieminister-vraagt-neder...                  Europese Unie
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...                        Politie
# 2338854-conservatief-duda-krijgt-meeste-stemmen...        Politiek & verkiezingen
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...                     Medicijnen
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...        Politiek & verkiezingen
# 2015000-gates-rijke-landen-moeten-investeren-in...             Klimaatverandering
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...                        Voetbal
# 2294649-zuid-korea-waarschuwt-russische-bommenw...                       Defensie
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...                    Koningshuis
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...                          Sport
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...                  Discriminatie
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...                    Scheepvaart
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...      Natuurramp & extreem weer
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...                          Sport
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...                          Islam
# grote-oefening-in-en-boven-nederland-in-volle-g...                       Defensie
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...                          China
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...                          Afval
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...                Cultuur & musea
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...                        Vliegen
# 2146388-meest-gezochte-criminelen-op-adventskal...                  Europese Unie
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...        Politiek & verkiezingen
# 2124713-australische-gevangene-vlucht-1000-km-m...                        Verkeer
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...                Cultuur & musea
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...                           Werk
# 2282169-wij-domineren-de-school-op-shisha-gebie...                      Onderwijs
# 2324549-noodopvang-asielzoekers-in-evenementenh...   Asielzoekers & vluchtelingen
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...                           Zorg
# 2247481-waarom-nederland-absolute-grootmacht-is...                        Politie
# 2351553-omt-adviseert-geen-standaard-preventief...                           Zorg
# 624421-pmt-verlaagt-pensioenen-toch.html.txt                             Pensioen
# 2072241-verdachten-sns-voor-de-rechter.html.txt                Corruptie & fraude
# 2346710-geen-reden-tot-onrust-over-loslopende-n...                    Coronavirus
# 2176446-adoptiekinderen-bangladesh-zonder-medew...                        Vliegen
#
#                                                            2  \
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...  0.979068
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...  0.995932
# 2265706-twee-belgische-kernreactoren-morgen-wee...  0.998795
# 362503-jagende-juan-carlos-in-opspraak.html.txt     0.994066
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...  0.994061
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...  0.611876
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt    0.380838
# militair-artsen-en-verpleegkundigen-aan-de-slag...  0.516343
# 2302970-dnb-president-knot-snel-beginnen-met-ko...  0.520742
# 2352429-haar-situatie-is-schrijnend-maar-nederl...  0.987325
# 407712-automobilist-eland-ontweken-beer-geraakt...  0.995937
# 2351459-eindhovense-studenten-presenteren-luca-...  0.958329
# 2275332-ministerie-voor-zover-bekend-geen-neder...  0.585086
# 2157810-milieuorganisaties-lanceren-groen-kiesk...  0.499572
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...  0.675720
# 2278194-marokkaanse-christenen-hopen-op-meer-re...  0.366895
# 2277311-afghaanse-migratieminister-vraagt-neder...  0.359650
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...  0.976952
# 2338854-conservatief-duda-krijgt-meeste-stemmen...  0.992721
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...  0.589745
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...  0.998250
# 2015000-gates-rijke-landen-moeten-investeren-in...  0.385181
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...  0.992751
# 2294649-zuid-korea-waarschuwt-russische-bommenw...  0.991568
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...  0.435534
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...  0.975359
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...  0.998298
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...  0.998286
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...  0.626040
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...  0.992813
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...  0.987911
# grote-oefening-in-en-boven-nederland-in-volle-g...  0.997158
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...  0.969506
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...  0.986138
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...  0.996895
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...  0.452234
# 2146388-meest-gezochte-criminelen-op-adventskal...  0.988969
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...  0.987288
# 2124713-australische-gevangene-vlucht-1000-km-m...  0.992717
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...  0.997529
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...  0.981733
# 2282169-wij-domineren-de-school-op-shisha-gebie...  0.978486
# 2324549-noodopvang-asielzoekers-in-evenementenh...  0.996241
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...  0.382416
# 2247481-waarom-nederland-absolute-grootmacht-is...  0.358327
# 2351553-omt-adviseert-geen-standaard-preventief...  0.534828
# 624421-pmt-verlaagt-pensioenen-toch.html.txt        0.978814
# 2072241-verdachten-sns-voor-de-rechter.html.txt     0.740663
# 2346710-geen-reden-tot-onrust-over-loslopende-n...  0.590586
# 2176446-adoptiekinderen-bangladesh-zonder-medew...  0.618830
#
#                                                                                3  \
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...                     Onderwijs
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...            Klimaatverandering
# 2265706-twee-belgische-kernreactoren-morgen-wee...     Natuurramp & extreem weer
# 362503-jagende-juan-carlos-in-opspraak.html.txt                            China
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...        Criminaliteit & geweld
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...                   Consumenten
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt          Criminaliteit & geweld
# militair-artsen-en-verpleegkundigen-aan-de-slag...                      Defensie
# 2302970-dnb-president-knot-snel-beginnen-met-ko...                        Banken
# 2352429-haar-situatie-is-schrijnend-maar-nederl...           Oorlog & conflicten
# 407712-automobilist-eland-ontweken-beer-geraakt...     Reizen & Openbaar vervoer
# 2351459-eindhovense-studenten-presenteren-luca-...                       Verkeer
# 2275332-ministerie-voor-zover-bekend-geen-neder...                       Vliegen
# 2157810-milieuorganisaties-lanceren-groen-kiesk...                       Verkeer
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...                         China
# 2278194-marokkaanse-christenen-hopen-op-meer-re...                     Onderwijs
# 2277311-afghaanse-migratieminister-vraagt-neder...  Asielzoekers & vluchtelingen
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...        Criminaliteit & geweld
# 2338854-conservatief-duda-krijgt-meeste-stemmen...                 Europese Unie
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...                          Zorg
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...                 Europese Unie
# 2015000-gates-rijke-landen-moeten-investeren-in...      Bedrijfsleven & economie
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...                         Sport
# 2294649-zuid-korea-waarschuwt-russische-bommenw...                       Vliegen
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...               Cultuur & musea
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...                       Voetbal
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...           Rechtbank & rechter
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...           Branden & brandweer
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...                           Gas
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...                       Voetbal
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...                   Christendom
# grote-oefening-in-en-boven-nederland-in-volle-g...           Oorlog & conflicten
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...                         Sport
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...           Branden & brandweer
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...        Aanslagen & terrorisme
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...                 Europese Unie
# 2146388-meest-gezochte-criminelen-op-adventskal...        Criminaliteit & geweld
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...                 Europese Unie
# 2124713-australische-gevangene-vlucht-1000-km-m...                       Politie
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...                     Onderwijs
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...                     Vakbonden
# 2282169-wij-domineren-de-school-op-shisha-gebie...      Bedrijfsleven & economie
# 2324549-noodopvang-asielzoekers-in-evenementenh...                   Woningmarkt
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...        Criminaliteit & geweld
# 2247481-waarom-nederland-absolute-grootmacht-is...        Criminaliteit & geweld
# 2351553-omt-adviseert-geen-standaard-preventief...                   Coronavirus
# 624421-pmt-verlaagt-pensioenen-toch.html.txt                              Banken
# 2072241-verdachten-sns-voor-de-rechter.html.txt              Rechtbank & rechter
# 2346710-geen-reden-tot-onrust-over-loslopende-n...               Natuur & dieren
# 2176446-adoptiekinderen-bangladesh-zonder-medew...       Zwangerschap & abortus
#
#                                                            4  \
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...  0.004085
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...  0.000761
# 2265706-twee-belgische-kernreactoren-morgen-wee...  0.000254
# 362503-jagende-juan-carlos-in-opspraak.html.txt     0.001521
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...  0.001513
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...  0.378551
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt    0.327368
# militair-artsen-en-verpleegkundigen-aan-de-slag...  0.462995
# 2302970-dnb-president-knot-snel-beginnen-met-ko...  0.457632
# 2352429-haar-situatie-is-schrijnend-maar-nederl...  0.002232
# 407712-automobilist-eland-ontweken-beer-geraakt...  0.000812
# 2351459-eindhovense-studenten-presenteren-luca-...  0.009006
# 2275332-ministerie-voor-zover-bekend-geen-neder...  0.385145
# 2157810-milieuorganisaties-lanceren-groen-kiesk...  0.471951
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...  0.291169
# 2278194-marokkaanse-christenen-hopen-op-meer-re...  0.364194
# 2277311-afghaanse-migratieminister-vraagt-neder...  0.220182
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...  0.014085
# 2338854-conservatief-duda-krijgt-meeste-stemmen...  0.001976
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...  0.406053
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...  0.000192
# 2015000-gates-rijke-landen-moeten-investeren-in...  0.234102
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...  0.006470
# 2294649-zuid-korea-waarschuwt-russische-bommenw...  0.003122
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...  0.345332
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...  0.013943
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...  0.000337
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...  0.000531
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...  0.362049
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...  0.004666
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...  0.004801
# grote-oefening-in-en-boven-nederland-in-volle-g...  0.001324
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...  0.015965
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...  0.002555
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...  0.000744
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...  0.332962
# 2146388-meest-gezochte-criminelen-op-adventskal...  0.003411
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...  0.007822
# 2124713-australische-gevangene-vlucht-1000-km-m...  0.004594
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...  0.001202
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...  0.004108
# 2282169-wij-domineren-de-school-op-shisha-gebie...  0.006664
# 2324549-noodopvang-asielzoekers-in-evenementenh...  0.001344
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...  0.362933
# 2247481-waarom-nederland-absolute-grootmacht-is...  0.344148
# 2351553-omt-adviseert-geen-standaard-preventief...  0.461497
# 624421-pmt-verlaagt-pensioenen-toch.html.txt        0.009666
# 2072241-verdachten-sns-voor-de-rechter.html.txt     0.251795
# 2346710-geen-reden-tot-onrust-over-loslopende-n...  0.348687
# 2176446-adoptiekinderen-bangladesh-zonder-medew...  0.357558
#
#                                                                                    5  \
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...                 Landbouw & boeren
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...                       Consumenten
# 2265706-twee-belgische-kernreactoren-morgen-wee...          Bedrijfsleven & economie
# 362503-jagende-juan-carlos-in-opspraak.html.txt                      Natuur & dieren
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...                       Woningmarkt
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...                              Werk
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt                 Rechtbank & rechter
# militair-artsen-en-verpleegkundigen-aan-de-slag...                       Coronavirus
# 2302970-dnb-president-knot-snel-beginnen-met-ko...                         Vakbonden
# 2352429-haar-situatie-is-schrijnend-maar-nederl...            Criminaliteit & geweld
# 407712-automobilist-eland-ontweken-beer-geraakt...               Oorlog & conflicten
# 2351459-eindhovense-studenten-presenteren-luca-...                       Consumenten
# 2275332-ministerie-voor-zover-bekend-geen-neder...                          Defensie
# 2157810-milieuorganisaties-lanceren-groen-kiesk...                Klimaatverandering
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...                           Vliegen
# 2278194-marokkaanse-christenen-hopen-op-meer-re...                             Islam
# 2277311-afghaanse-migratieminister-vraagt-neder...               Oorlog & conflicten
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...                     Demonstraties
# 2338854-conservatief-duda-krijgt-meeste-stemmen...                              Zorg
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...          Bedrijfsleven & economie
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...                              Werk
# 2015000-gates-rijke-landen-moeten-investeren-in...                     Europese Unie
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...                     Europese Unie
# 2294649-zuid-korea-waarschuwt-russische-bommenw...                        Diplomatie
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...                          Defensie
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...                     Europese Unie
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...                           Voetbal
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...      Asielzoekers & vluchtelingen
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...          Bedrijfsleven & economie
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...                              Werk
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...               Rechtbank & rechter
# grote-oefening-in-en-boven-nederland-in-volle-g...                   Natuur & dieren
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...                              Werk
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...                Klimaatverandering
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...                         Onderwijs
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...                              Werk
# 2146388-meest-gezochte-criminelen-op-adventskal...                Klimaatverandering
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...                Klimaatverandering
# 2124713-australische-gevangene-vlucht-1000-km-m...               Rechtbank & rechter
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...                              Werk
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...                          Pensioen
# 2282169-wij-domineren-de-school-op-shisha-gebie...                       Consumenten
# 2324549-noodopvang-asielzoekers-in-evenementenh...                     Europese Unie
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...  Seksueel misbruik & seksualiteit
# 2247481-waarom-nederland-absolute-grootmacht-is...             Criminaliteit & drugs
# 2351553-omt-adviseert-geen-standaard-preventief...               Rechtbank & rechter
# 624421-pmt-verlaagt-pensioenen-toch.html.txt                Bedrijfsleven & economie
# 2072241-verdachten-sns-voor-de-rechter.html.txt                             Defensie
# 2346710-geen-reden-tot-onrust-over-loslopende-n...                 Landbouw & boeren
# 2176446-adoptiekinderen-bangladesh-zonder-medew...                              Zorg
#
#                                                            6
# 0
# 2319387-ongelijkheid-blijft-groeien-rijken-beta...  0.003547
# 2163856-topman-audi-in-vizier-vanwege-dieselfra...  0.000601
# 2265706-twee-belgische-kernreactoren-morgen-wee...  0.000141
# 362503-jagende-juan-carlos-in-opspraak.html.txt     0.000727
# 2309604-5000-nieuwe-opvangplekken-nodig-voor-as...  0.000809
# 2335040-tijdelijk-verbod-op-uitverkoop-komt-er-...  0.001795
# 540468-om-geeft-fout-toe-in-zaak-donnie.html.txt    0.272065
# militair-artsen-en-verpleegkundigen-aan-de-slag...  0.003493
# 2302970-dnb-president-knot-snel-beginnen-met-ko...  0.006360
# 2352429-haar-situatie-is-schrijnend-maar-nederl...  0.002188
# 407712-automobilist-eland-ontweken-beer-geraakt...  0.000618
# 2351459-eindhovense-studenten-presenteren-luca-...  0.008674
# 2275332-ministerie-voor-zover-bekend-geen-neder...  0.010486
# 2157810-milieuorganisaties-lanceren-groen-kiesk...  0.006121
# 2332972-pandababy-in-rhenen-met-uitzonderlijk-l...  0.006884
# 2278194-marokkaanse-christenen-hopen-op-meer-re...  0.230188
# 2277311-afghaanse-migratieminister-vraagt-neder...  0.218960
# 2335526-cnn-ploeg-weer-vrijgelaten-na-arrestati...  0.004351
# 2338854-conservatief-duda-krijgt-meeste-stemmen...  0.001522
# 2129097-big-data-gebruikt-om-sterfte-aan-bloedv...  0.001639
# 2293806-peilingwijzer-pvda-en-vvd-omhoog-sp-en-...  0.000174
# 2015000-gates-rijke-landen-moeten-investeren-in...  0.214218
# 2300676-voetbalsters-psv-en-twente-winnen-ook-t...  0.000166
# 2294649-zuid-korea-waarschuwt-russische-bommenw...  0.001232
# 2332665-dit-zijn-de-extra-nos-uitzendingen-met-...  0.191604
# 2285889-sparta-wint-ook-thuis-van-top-oss-en-ha...  0.008757
# 2299958-knvb-gaat-discriminatie-in-amateurvoetb...  0.000312
# 2178624-marineschip-vs-gestabiliseerd-na-aanvar...  0.000243
# 2214899-maximaal-12-miljard-kuub-gas-de-overhei...  0.004741
# 2319274-dumoulin-staat-te-popelen-ik-wil-die-ex...  0.000901
# 2208883-mostafa-en-charif-vieren-wel-geen-kerst...  0.001896
# grote-oefening-in-en-boven-nederland-in-volle-g...  0.000159
# 2288958-china-boekt-zuinige-maar-nuttige-zege-o...  0.002525
# 2284593-miljonair-duikt-naar-diepste-punt-van-d...  0.002499
# 2255004-nachtwacht-van-rembrandt-voor-oog-van-p...  0.000619
# 2184941-easyjet-zoekt-ruim-1200-stewards-en-ste...  0.186009
# 2146388-meest-gezochte-criminelen-op-adventskal...  0.001214
# 2178729-het-wordt-een-moeilijk-beroep-maar-ik-h...  0.000972
# 2124713-australische-gevangene-vlucht-1000-km-m...  0.000624
# 2317440-bruggenbouwers-leer-je-buren-kennen-bes...  0.000511
# 2329882-ook-spelers-en-staf-real-madrid-akkoord...  0.002511
# 2282169-wij-domineren-de-school-op-shisha-gebie...  0.003780
# 2324549-noodopvang-asielzoekers-in-evenementenh...  0.000607
# 2199247-michael-p-had-niet-in-kliniek-den-dolde...  0.215900
# 2247481-waarom-nederland-absolute-grootmacht-is...  0.266482
# 2351553-omt-adviseert-geen-standaard-preventief...  0.000523
# 624421-pmt-verlaagt-pensioenen-toch.html.txt        0.003583
# 2072241-verdachten-sns-voor-de-rechter.html.txt     0.000980
# 2346710-geen-reden-tot-onrust-over-loslopende-n...  0.013284
# 2176446-adoptiekinderen-bangladesh-zonder-medew...  0.004770

# %% [markdown]
# # Verkiezingsprogrammas

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
used_words_for_training =  X_sel.columns.tolist()

# %%
partijen = [p.strip('.pdf') for p in os.listdir('Data/Verkiezingsprogrammas/')]

# Some error occured with this document, need to be fixed
partijen.remove('DENK')

# %%
for partij in partijen:
    
    file = 'Results/{}_topics_over_doc.csv'.format(partij)
    if( not os.path.exists(file) ):
    
        path = 'Data/Verkiezingsprogrammas/{}.pdf'.format(partij)
        text_pdf = convert_pdf_to_txt(path)
        text_pdf_clean = re.sub('[^A-Za-z0-9 ]+', '', text_pdf).lower().split(' ')

        res = []
        blocksize= 60
        ii = np.arange(0,len(text_pdf_clean), int( blocksize / 3) )
        for k,i in enumerate(ii):
            print(k,len(ii))

            w = text_pdf_clean[ i : i + blocksize  ]

            w = [ el for el in w if len(el) > 1]
            ws = []
            for el in w:
                ws.extend( [ el_.lower() for el_ in el.split(' ') if len(el_) > 1] )
            ws = pd.Series(ws).value_counts()

            ws.name = 'verkiezingsprogramma'
            ws = ws.loc[ set(used_words_for_training).intersection(ws.index) ]
            diff_words = list(set(used_words_for_training).difference(ws.index))
            ws = ws.append(pd.Series( np.zeros(len(diff_words)),index = diff_words)) 
            
            # Normalize word counts
            ws = ws / ws.sum()        
 
            x = ws.reset_index().set_index('index').T
            x = x[used_words_for_training]

            probs = pd.DataFrame(model.predict(x), index = x.index ).rename(columns = nr_to_label )

            x = probs.iloc[0]
            x.name = i
            res.append(x)


        topics_over_doc = pd.DataFrame(res)
        topics_over_doc.to_csv(file)

# %% [markdown]
# # Top 30 most discussed topics per party

# %%
topics_over_doc = pd.DataFrame([])
for partij in partijen:
    df = pd.read_csv( 'Results/{}_topics_over_doc.csv'.format(partij) ).rename( columns = {'Unnamed: 0':'step'})
    df['partij'] = partij
    topics_over_doc = pd.concat([topics_over_doc,df])

# %%
fig = plt.figure(figsize = (60,60))
fig.subplots_adjust(hspace=0.8, wspace=0.2)

ls = topics_over_doc.drop(columns = ['partij','step']).columns.tolist()
ls = random.sample(ls,len(ls))

colors = sns.color_palette('Spectral', int(len(ls)) ) 
color = { k:c for k,c in zip(ls, colors ) }

bar_width = 0.5
for i,(partij, data_partij) in enumerate(topics_over_doc.groupby('partij')):
    ax = fig.add_subplot(4,4,1+i)
    
    probs = data_partij.set_index('step').drop(columns = ['partij'])
    
    perc = probs[probs > 0.1].fillna(0).sum(axis=0)
    perc = (perc / perc.sum() *100).sort_values(ascending=False)
    perc.to_csv('Results/{}_verdeling.csv'.format(partij))
    
    

    xticks = []
    xticklabels = []
    for ii,(name, val) in enumerate(perc.iloc[0:30].items() ):
        x_pos = ii
        ax.bar([x_pos*bar_width +1], [val], width=bar_width, bottom = 0, color= color[name],linewidth=4, edgecolor='w')
        xticks.append(x_pos*bar_width +1)
        xticklabels.append(name.replace('_',' & '))

    ax.set_title(partij,fontsize=30)
    ax.set_xticks(xticks)
    _ = ax.set_xticklabels(xticklabels, rotation= 90, fontsize=20)
    ax.set_ylabel('Percentage',fontsize=20)

# %% [markdown]
# # Comparing the political parties per topic

# %%
df = []
for file in os.listdir('Results/'):
    if( '_verdeling' in file):
        df_ = pd.read_csv('Results/'+file).set_index('Unnamed: 0')
        df_.columns = [file.strip('_verdeling.csv')]
        df.append(df_.iloc[:,0])
        
        
verdeling = pd.DataFrame(df)

# %%
fig = plt.figure(figsize = (80,50))
fig.subplots_adjust(hspace=0.4, wspace=0.3)

k = 0
for topic,x in verdeling[verdeling.sum().sort_values(ascending=False).index].items():
    x = x.fillna(0).sort_values(ascending= False)
    k+=1
    ax = fig.add_subplot(6,11,k)

    xticks = []
    xticklabels = []
    for i,(name, val) in enumerate(x.items() ):
        x_pos = i
        ax.bar([x_pos*bar_width +1], [val], width=bar_width, bottom = 0, color= color[topic],linewidth=4, edgecolor='w')
        xticks.append(x_pos*bar_width +1)
        xticklabels.append(name.replace('_',' & '))


    ax.set_xticks(xticks)
    _ = ax.set_xticklabels(xticklabels, rotation= 90, fontsize=15)
    ax.set_ylabel('Percentage',fontsize=15)
    ax.set_title(topic,fontsize=20)

# %% [markdown]
# # Heatmap

# %%
verdeling_sel = verdeling.loc[ :, verdeling.max() > 1]
Z  = (verdeling_sel.fillna(0) - verdeling_sel.fillna(0).mean())/ (verdeling_sel.fillna(0).std() )

# %%
sns.clustermap(Z, cmap='RdBu_r', figsize=(30,15), vmin=-2.5,vmax=2.5,annot=True,linewidth=1)
